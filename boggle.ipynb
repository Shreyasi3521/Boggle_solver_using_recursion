# %%
import random
import string 
import collections
from bisect import bisect_left
import time
import multiprocessing

#function to get the dictionary words from file "words.txt" letter wise
def Dictionary(fname="words.txt"):
    words = collections.defaultdict(list)
    with open(fname) as f:
        for word in f.readlines():
            if len(word) > 3:
                words[word[0]].append(word.strip())
    return words

#generating a random grid of desired size
def Grid(size=8):
    grid = [[random.choice(string.ascii_lowercase) for c in range(size)] for r in range(size)]
    return grid

#Given: grid, position of letter whose adjecents are to be found(r,c)
#returns turple of (letter, row index, column index) for each index of given letter
#origin: top left corner
def AdjacentLetters(grid, r, c):
    gsize = len(grid)
    # indexes of all neighbours for a given cell
    neighbours = [ [(r-1,c-1),(r-1,c),(r-1,c+1)],
                   [(r,c-1),          (r,c+1)],
                    [(r+1,c-1),(r+1,c) ,(r+1,c+1)] ]

    #removing non existing neighbours
    if c == 0:
        res = [n[1:] for n in neighbours]
    elif c == gsize-1:
        res = [neighbours[0][0:2], [neighbours[1][0]], neighbours[2][0:2]]
    else:
        res = neighbours
    if r == 0:
        res = res[1:]
    elif r == gsize-1:
        res = res[0:2]
    else:
        pass

    letters = []
    for row in res:
        letters.extend( [(grid[r][c],r,c) for r,c in row] )
    return letters

def PrefixMatches(word, dictionary):
    return [m for m in dictionary[word[0]] if m.startswith(word)]

def isValidWord(word,dictionary):
    return word in dictionary[word[0]]

def getWords(grid,dictionary,seed_letter,ply=64):
    # recursive function using depth first traversal
    def genCandidates(results, seed_letter, ignored, curWord=""):
        if len(curWord) > ply:
            " -> maximum ply of %s reached, baling out" % ply
            return
        else:
            print("  trying ",curWord)
        if isValidWord(curWord,dictionary):
            results.add(curWord)
            print("    -> match: ",curWord)
            
        # make sure we dont visit the same letter twice
        ignored.add(seed_letter)

        # the neighbours of the seed cell
        neighbours = getAdjacentLetters(grid,seed_letter[1],seed_letter[2])
        
        # remove cells we have visited before by checking against the ignored list
        candidates = [n for n in neighbours if n not in ignored]
        
        # see how many words we can find for each candidate prefix
        num_matches = [len(getPrefixMatches(curWord + n[0], dictionary)) for n in candidates]
        
        # zip them together in a convenient list of tuples
        matches = zip(candidates,num_matches)
        
        # for each candidate with more than 0 matches recursively call the function
        for c,numMatches in matches:
            if numMatches > 0:
                genCandidates(results,c,ignored,curWord=curWord + c[0])

    results = set()
    genCandidates(results,seed_letter,set(),curWord=seed_letter[0])
    print("**********")
    print("Seed: ", seed_letter)
    print("--> %s words" % len(results))
    print("**********")
    return results

def solve(grid,dictionary,seeds,ply):
    totResults = set()
    
    # iterate over every seed sequentially
    for seed in seeds:
        # the actual computation			
        results = getWords(grid,dictionary,seed,ply=ply)
        totResults = totResults.union(results)
    return totResults

#to display grid
def print_grid(grid):
    for r in grid:
        print(r)



dictionary = getDictionary()
gsize = 8  # grid size
ply = 64   # max word length

# a random grid
grid = Grid(size=gsize)

# display the grid
print_grid(grid)

# build the list of seed tuples (letter,row_idx,col_idx) for every item in the grid
seeds = []
for r,row in enumerate(grid):
    for c,letter in enumerate(row):
        seeds.append( (letter,r,c) )

# start the timer
tstart = time.time();

# Solving boggle
results = solve(grid,dictionary,seeds,ply)

print("=======================================================================================================")
print("%s words with max %s letters found in a %sx%s grid after %s seconds: " % (len(results),ply,gsize,gsize,time.time() - tstart))
print()
print("   ",",".join(sorted(results)))
print("=======================================================================================================")
# Out:
# ['q', 'l', 'f', 'o', 'p', 'c', 'q', 'h']
# ['b', 's', 't', 'o', 'n', 'c', 'z', 'y']
# ['g', 'h', 'r', 'g', 'e', 'i', 'c', 'b']
# ['z', 'i', 'm', 'u', 'l', 'v', 'r', 'b']
# ['b', 'z', 'q', 's', 'z', 'k', 'q', 'r']
# ['b', 'r', 'k', 'v', 'n', 'a', 'l', 'z']
# ['v', 't', 'c', 'u', 'a', 'f', 'f', 'y']
# ['x', 'a', 'c', 'm', 'h', 'x', 'c', 't']
#   trying  q
# **********
# Seed:  ('q', 0, 0)
# --> 0 words
# **********
#   trying  l
#   trying  lb
#   trying  lbs
#     -> match:  lbs
# **********
# Seed:  ('l', 0, 1)
# --> 1 words
# **********
#   trying  f
#   trying  fl
#   trying  fo
#   trying  fop
#     -> match:  fop
#   trying  foo
#   trying  foot
#     -> match:  foot
#   trying  foots
#     -> match:  foots
#   trying  footh
#   trying  foothi
#   trying  footr
#   trying  footg
#   trying  footge
#   trying  fon
#   trying  ft
#   trying  fo
# **********
# Seed:  ('f', 0, 2)
# --> 3 words
# **********
#   trying  o
#   trying  of
#   trying  oft
#     -> match:  oft
#   trying  op
#   trying  opc
#   trying  opo
#   trying  opc
#   trying  ot
#   trying  oth
#   trying  oo
#   trying  on
#   trying  ong
#   trying  one
#     -> match:  one
#   trying  oni
# **********
# Seed:  ('o', 0, 3)
# --> 2 words
# **********
#   trying  p
#   trying  po
#   trying  pot
#     -> match:  pot
#   trying  potl
#   trying  pots
#     -> match:  pots
#   trying  potsh
#   trying  poth
#   trying  poo
#   trying  poof
#     -> match:  poof
#   trying  poor
#     -> match:  poor
#   trying  pon
#   trying  ponc
#   trying  ponc
#   trying  pong
#     -> match:  pong
#   trying  ponge
#   trying  pone
#     -> match:  pone
#   trying  poni
#   trying  po
#   trying  pn
# **********
# Seed:  ('p', 0, 4)
# --> 6 words
# **********
#   trying  c
#   trying  cz
# **********
# Seed:  ('c', 0, 5)
# --> 0 words
# **********
#   trying  q
# **********
# Seed:  ('q', 0, 6)
# --> 0 words
# **********
#   trying  h
#   trying  hy
#   trying  hyb
#   trying  hybr
#   trying  hybri
# **********
# Seed:  ('h', 0, 7)
# --> 0 words
# **********
#   trying  b
#   trying  bl
#   trying  bh
# **********
# Seed:  ('b', 1, 0)
# --> 0 words
# **********
#   trying  s
#   trying  sq
#   trying  sl
#   trying  st
#   trying  sto
#   trying  stop
#     -> match:  stop
#   trying  stopc
#   trying  stopo
#   trying  stopc
#   trying  stoo
#   trying  stoog
#   trying  stooge
#     -> match:  stooge
#   trying  ston
#   trying  stoni
#   trying  stonil
#   trying  sto
#   trying  stor
#   trying  stori
#   trying  storm
#     -> match:  storm
#   trying  storms
#     -> match:  storms
#   trying  str
#   trying  stru
#   trying  sh
# **********
# Seed:  ('s', 1, 1)
# --> 4 words
# **********
#   trying  t
#   trying  to
#   trying  tof
#   trying  top
#     -> match:  top
#   trying  topc
#   trying  topo
#   trying  topog
#   trying  topogr
#   trying  topc
#   trying  too
#     -> match:  too
#   trying  ton
#     -> match:  ton
#   trying  tone
#     -> match:  tone
#   trying  tonel
#   trying  toni
#   trying  tonic
#     -> match:  tonic
#   trying  ts
#   trying  to
#   trying  th
#   trying  thi
#   trying  thig
#   trying  thim
#   trying  tr
#   trying  tru
#   trying  trus
# **********
# Seed:  ('t', 1, 2)
# --> 5 words
# **********
#   trying  o
#   trying  of
#   trying  oft
#     -> match:  oft
#   trying  oo
#   trying  oop
#   trying  op
#   trying  opc
#   trying  opc
#   trying  ot
#   trying  oth
#   trying  on
#   trying  ong
#   trying  one
#     -> match:  one
#   trying  oni
#   trying  or
#   trying  ori
#   trying  orig
#   trying  orm
#   trying  og
#   trying  ogl
#   trying  oe
#   trying  oeu
# **********
# Seed:  ('o', 1, 3)
# --> 2 words
# **********
#   trying  n
#   trying  no
#   trying  nop
#   trying  not
#     -> match:  not
#   trying  noto
#   trying  notor
#   trying  notori
#   trying  noth
#   trying  noo
#   trying  no
#   trying  nog
#   trying  ne
#   trying  nec
#   trying  nei
#   trying  neu
#   trying  nel
#   trying  nels
#   trying  nev
#   trying  ni
#   trying  nic
#   trying  nir
# **********
# Seed:  ('n', 1, 4)
# --> 1 words
# **********
#   trying  c
#   trying  cz
#   trying  ce
#   trying  cen
#   trying  ceno
#   trying  cenot
#   trying  ceno
#   trying  cei
#   trying  ceil
#     -> match:  ceil
#   trying  cel
#   trying  ci
#   trying  cic
#   trying  civ
#   trying  cir
#   trying  cirq
#   trying  cirr
# **********
# Seed:  ('c', 1, 5)
# --> 1 words
# **********
#   trying  z
#   trying  zy
#   trying  zi
#   trying  zin
#   trying  zinc
#     -> match:  zinc
#   trying  zinc
#     -> match:  zinc
#   trying  zing
#     -> match:  zing
#   trying  zinge
#   trying  zil
#   trying  zir
#   trying  zirc
# **********
# Seed:  ('z', 1, 6)
# --> 2 words
# **********
#   trying  y
#   trying  yc
# **********
# Seed:  ('y', 1, 7)
# --> 0 words
# **********
#   trying  g
#   trying  gh
#   trying  gi
#   trying  gir
#   trying  girt
#     -> match:  girt
#   trying  giro
#     -> match:  giro
#   trying  giz
#   trying  gizz
#   trying  gim
#   trying  gib
#   trying  gibb
#   trying  giz
# **********
# Seed:  ('g', 2, 0)
# --> 2 words
# **********
#   trying  h
#   trying  ht
#   trying  hr
#   trying  hrs
#     -> match:  hrs
#   trying  hi
#   trying  hig
#   trying  him
#     -> match:  him
#   trying  hims
#   trying  hib
#   trying  hm
# **********
# Seed:  ('h', 2, 1)
# --> 2 words
# **********
#   trying  r
#   trying  ro
#   trying  roo
#   trying  roof
#     -> match:  roof
#   trying  roofl
#   trying  roofs
#     -> match:  roofs
#   trying  rooft
#   trying  root
#     -> match:  root
#   trying  rooth
#   trying  rop
#   trying  rot
#     -> match:  rot
#   trying  rotg
#   trying  rotgu
#   trying  ron
#   trying  rog
#   trying  roe
#     -> match:  roe
#   trying  rh
#   trying  rhi
#   trying  rhiz
#   trying  rhiz
#   trying  ri
#   trying  rig
#     -> match:  rig
#   trying  rim
#     -> match:  rim
#   trying  rims
#     -> match:  rims
#   trying  rib
#     -> match:  rib
#   trying  ribb
#   trying  ru
#   trying  rul
#   trying  ruli
# **********
# Seed:  ('r', 2, 2)
# --> 9 words
# **********
#   trying  g
#   trying  go
#   trying  goo
#   trying  goof
#     -> match:  goof
#   trying  goofs
#     -> match:  goofs
#   trying  goon
#     -> match:  goon
#   trying  goone
#   trying  gop
#   trying  got
#     -> match:  got
#   trying  gon
#   trying  gor
#   trying  gori
#   trying  gorm
#   trying  goe
#   trying  gn
#   trying  gr
#   trying  gru
#   trying  ge
#   trying  gec
#   trying  gei
#   trying  gel
#     -> match:  gel
#   trying  gels
#     -> match:  gels
#   trying  gu
#   trying  guz
#   trying  gl
# **********
# Seed:  ('g', 2, 3)
# --> 6 words
# **********
#   trying  e
#   trying  eo
#   trying  eon
#     -> match:  eon
#   trying  en
#   trying  eno
#   trying  enp
#   trying  enc
#   trying  enc
#   trying  enci
#   trying  encir
#   trying  encirc
#   trying  eng
#   trying  engr
#   trying  engu
#   trying  engul
#   trying  eni
#   trying  ec
#   trying  ecz
#   trying  eg
#   trying  ei
#   trying  eu
#   trying  eus
#   trying  el
#   trying  elv
#   trying  elk
#     -> match:  elk
#   trying  ev
# **********
# Seed:  ('e', 2, 4)
# --> 2 words
# **********
#   trying  i
#   trying  in
#   trying  ino
#   trying  inof
#   trying  inop
#   trying  inp
#   trying  inc
#   trying  ino
#   trying  inor
#   trying  inorg
#   trying  inc
#   trying  ince
#   trying  ing
#   trying  ingu
#   trying  ingl
#   trying  ine
#   trying  inev
#   trying  ic
#   trying  ic
#   trying  icy
#     -> match:  icy
#   trying  il
#   trying  ilk
#     -> match:  ilk
#   trying  iv
#   trying  ir
#   trying  irr
# **********
# Seed:  ('i', 2, 5)
# --> 2 words
# **********
#   trying  c
#   trying  cz
#   trying  cy
#   trying  cyb
#   trying  ci
#   trying  cin
#   trying  cinc
#   trying  cinc
#   trying  cine
#     -> match:  cine
#   trying  cineo
#   trying  cic
#   trying  cil
#   trying  civ
#   trying  cir
#   trying  cirq
#   trying  cirr
#   trying  cr
# **********
# Seed:  ('c', 2, 6)
# --> 1 words
# **********
#   trying  b
#   trying  by
#   trying  br
#   trying  bri
#   trying  brin
#   trying  bring
#     -> match:  bring
#   trying  bringe
#   trying  brine
#     -> match:  brine
#   trying  bric
#   trying  brie
#     -> match:  brie
#   trying  bric
#   trying  bril
# **********
# Seed:  ('b', 2, 7)
# --> 3 words
# **********
#   trying  z
#   trying  zi
#   trying  zig
#   trying  zir
#   trying  zib
#   trying  ziz
# **********
# Seed:  ('z', 3, 0)
# --> 0 words
# **********
#   trying  i
#   trying  ig
#   trying  ih
#   trying  ihr
#   trying  ir
#   trying  iro
#   trying  iron
#     -> match:  iron
#   trying  ironc
#   trying  ironc
#   trying  irone
#   trying  ironi
#   trying  ironic
#     -> match:  ironic
#   trying  im
#   trying  ib
# **********
# Seed:  ('i', 3, 1)
# --> 2 words
# **********
#   trying  m
#   trying  mh
#   trying  mi
#   trying  mig
#   trying  mir
#   trying  mirt
#   trying  miz
#   trying  mizz
#   trying  miz
#   trying  mu
#   trying  mug
#     -> match:  mug
#   trying  mue
#   trying  muen
#   trying  mul
#   trying  muli
#   trying  mus
#   trying  musk
#     -> match:  musk
#   trying  muskr
#   trying  muz
#   trying  mz
# **********
# Seed:  ('m', 3, 2)
# --> 2 words
# **********
#   trying  u
#   trying  ur
#   trying  urs
#   trying  uro
#   trying  urg
#   trying  urge
#     -> match:  urge
#   trying  urgen
#   trying  urgenc
#   trying  urgenc
#   trying  urgenci
#   trying  uri
#   trying  ug
#   trying  ugl
#   trying  um
#   trying  ul
#   trying  us
# **********
# Seed:  ('u', 3, 3)
# --> 1 words
# **********
#   trying  l
#   trying  le
#   trying  leo
#   trying  leop
#   trying  leot
#   trying  leon
#   trying  leoni
#   trying  len
#   trying  leng
#   trying  lec
#   trying  leg
#     -> match:  leg
#   trying  legr
#   trying  legm
#   trying  legu
#   trying  lei
#     -> match:  lei
#   trying  leu
#   trying  lev
#   trying  li
#   trying  liz
#   trying  lic
#   trying  lir
#   trying  lu
#   trying  lus
#   trying  lv
# **********
# Seed:  ('l', 3, 4)
# --> 2 words
# **********
#   trying  v
#   trying  ve
#   trying  ven
#   trying  veno
#   trying  veno
#   trying  veng
#   trying  veni
#   trying  venir
#   trying  vec
#   trying  veg
#   trying  vei
#   trying  veil
#     -> match:  veil
#   trying  veils
#     -> match:  veils
#   trying  vel
#   trying  velu
#   trying  velum
#     -> match:  velum
#   trying  vi
#   trying  viz
#   trying  vic
#   trying  vr
# **********
# Seed:  ('v', 3, 5)
# --> 3 words
# **********
#   trying  r
#   trying  ri
#   trying  rin
#   trying  ring
#     -> match:  ring
#   trying  ringt
#   trying  ringe
#   trying  ringm
#   trying  ringl
#   trying  ric
#   trying  ric
#   trying  ril
#   trying  riv
# **********
# Seed:  ('r', 3, 6)
# --> 1 words
# **********
#   trying  b
#   trying  br
#   trying  bri
#   trying  brin
#   trying  bring
#     -> match:  bring
#   trying  bringe
#   trying  brine
#     -> match:  brine
#   trying  bric
#   trying  brie
#     -> match:  brie
#   trying  bric
#   trying  bril
#   trying  br
# **********
# Seed:  ('b', 3, 7)
# --> 3 words
# **********
#   trying  b
#   trying  bi
#   trying  big
#     -> match:  big
#   trying  bigh
#   trying  bight
#     -> match:  bight
#   trying  bights
#     -> match:  bights
#   trying  bir
#   trying  biro
#     -> match:  biro
#   trying  biz
#     -> match:  biz
#   trying  bim
#   trying  biz
#     -> match:  biz
#   trying  biq
#   trying  biqu
#   trying  br
# **********
# Seed:  ('b', 4, 0)
# --> 5 words
# **********
#   trying  z
#   trying  zi
#   trying  zig
#   trying  zigz
#   trying  zir
#   trying  ziz
#   trying  zib
# **********
# Seed:  ('z', 4, 1)
# --> 0 words
# **********
#   trying  q
#   trying  qu
#   trying  que
#   trying  quen
#   trying  quenc
#   trying  quenc
#   trying  quel
# **********
# Seed:  ('q', 4, 2)
# --> 0 words
# **********
#   trying  s
#   trying  sm
#   trying  smi
#   trying  smir
#   trying  smu
#   trying  smug
#     -> match:  smug
#   trying  smugn
#   trying  smugne
#   trying  smugl
#   trying  su
#   trying  suz
#   trying  sl
#   trying  sli
#   trying  slic
#   trying  slic
#   trying  sliv
#   trying  sq
#   trying  sk
#   trying  sku
#   trying  skun
#   trying  skunk
#     -> match:  skunk
#   trying  sv
#   trying  sn
#   trying  sna
#   trying  snaf
#   trying  snaff
#   trying  snaffl
#   trying  snaf
#   trying  sna
# **********
# Seed:  ('s', 4, 3)
# --> 2 words
# **********
#   trying  z
#   trying  zu
#   trying  zl
#   trying  za
#   trying  zan
# **********
# Seed:  ('z', 4, 4)
# --> 0 words
# **********
#   trying  k
#   trying  kl
#   trying  kle
#   trying  kli
#   trying  klu
#   trying  kr
#   trying  kn
#   trying  kna
#   trying  knu
#   trying  knuc
#   trying  knuck
#   trying  knuc
#   trying  kna
#   trying  knav
#   trying  ka
#   trying  kaz
#   trying  kal
#   trying  kl
#   trying  kly
# **********
# Seed:  ('k', 4, 5)
# --> 0 words
# **********
#   trying  q
# **********
# Seed:  ('q', 4, 6)
# --> 0 words
# **********
#   trying  r
# **********
# Seed:  ('r', 4, 7)
# --> 0 words
# **********
#   trying  b
#   trying  br
# **********
# Seed:  ('b', 5, 0)
# --> 0 words
# **********
#   trying  r
# **********
# Seed:  ('r', 5, 1)
# --> 0 words
# **********
#   trying  k
#   trying  kr
#   trying  kc
#   trying  kca
#   trying  ku
#   trying  kum
# **********
# Seed:  ('k', 5, 2)
# --> 0 words
# **********
#   trying  v
#   trying  vu
#   trying  va
#   trying  van
#     -> match:  van
#   trying  vans
#     -> match:  vans
#   trying  vana
#   trying  vam
# **********
# Seed:  ('v', 5, 3)
# --> 2 words
# **********
#   trying  n
#   trying  na
#   trying  nak
#   trying  nu
#   trying  nuk
#   trying  nuc
#   trying  nua
#   trying  nuc
#   trying  num
#   trying  na
#   trying  nav
# **********
# Seed:  ('n', 5, 4)
# --> 0 words
# **********
#   trying  a
#   trying  az
#   trying  azu
#   trying  azur
#   trying  azuri
#   trying  ak
#   trying  aq
#   trying  an
#   trying  ans
#   trying  anv
#   trying  anu
#   trying  ana
#   trying  anam
#   trying  anf
#   trying  al
#   trying  alr
#   trying  alf
#   trying  aly
#   trying  aa
#   trying  af
#   trying  af
#   trying  aft
#     -> match:  aft
# **********
# Seed:  ('a', 5, 5)
# --> 1 words
# **********
#   trying  l
#   trying  la
#   trying  laz
#   trying  lazu
#   trying  lazul
#   trying  lazuli
#     -> match:  lazuli
#   trying  lak
#   trying  lan
#   trying  lans
#   trying  lansq
#   trying  lana
#   trying  ly
#   trying  lyc
# **********
# Seed:  ('l', 5, 6)
# --> 1 words
# **********
#   trying  z
#   trying  zl
#   trying  zy
# **********
# Seed:  ('z', 5, 7)
# --> 0 words
# **********
#   trying  v
#   trying  vr
#   trying  va
#   trying  vat
#     -> match:  vat
#   trying  vac
#   trying  vacu
#   trying  vacc
#   trying  vac
# **********
# Seed:  ('v', 6, 0)
# --> 1 words
# **********
#   trying  t
#   trying  tr
#   trying  ta
#   trying  tav
#   trying  tac
#   trying  tack
#     -> match:  tack
#   trying  tacks
#     -> match:  tacks
#   trying  tax
#     -> match:  tax
#   trying  tac
# **********
# Seed:  ('t', 6, 1)
# --> 3 words
# **********
#   trying  c
#   trying  cr
#   trying  ct
#   trying  cu
#   trying  cun
#   trying  cuc
#   trying  cum
#     -> match:  cum
#   trying  ca
#   trying  cav
# **********
# Seed:  ('c', 6, 2)
# --> 1 words
# **********
#   trying  u
#   trying  uk
#   trying  uv
#   trying  un
#   trying  uns
#   trying  unsm
#   trying  unsmi
#   trying  unsu
#   trying  unsur
#   trying  unz
#   trying  unk
#   trying  una
#   trying  unal
#   trying  unaf
#   trying  unaff
#   trying  unaf
#   trying  una
#   trying  unam
#   trying  unf
#   trying  um
# **********
# Seed:  ('u', 6, 3)
# --> 0 words
# **********
#   trying  a
#   trying  av
#   trying  avu
#   trying  avun
#   trying  an
#   trying  ans
#   trying  ank
#   trying  ankl
#   trying  ankle
#     -> match:  ankle
#   trying  ankl
#   trying  ana
#   trying  anf
#   trying  aa
#   trying  au
#   trying  auk
#     -> match:  auk
#   trying  auc
#   trying  auct
#   trying  auc
#   trying  af
#   trying  aff
#   trying  am
#   trying  ah
#   trying  ax
# **********
# Seed:  ('a', 6, 4)
# --> 2 words
# **********
#   trying  f
#   trying  fa
#   trying  faz
#   trying  fak
#   trying  fan
#     -> match:  fan
#   trying  fans
#     -> match:  fans
#   trying  fana
#   trying  fal
#   trying  fl
#   trying  fly
#     -> match:  fly
#   trying  flyc
#   trying  flyt
#   trying  fa
#   trying  fav
#   trying  fau
#   trying  fauc
#   trying  fauca
#   trying  fauc
#   trying  fam
#   trying  fax
#     -> match:  fax
# **********
# Seed:  ('f', 6, 5)
# --> 4 words
# **********
#   trying  f
#   trying  fa
#   trying  faz
#   trying  fak
#   trying  fan
#     -> match:  fan
#   trying  fans
#     -> match:  fans
#   trying  fana
#   trying  fanf
#   trying  fal
#   trying  fl
#   trying  fly
#     -> match:  fly
#   trying  flyc
#   trying  flyt
#   trying  fy
#   trying  ft
# **********
# Seed:  ('f', 6, 6)
# --> 3 words
# **********
#   trying  y
#   trying  yl
#   trying  yc
#   trying  yt
# **********
# Seed:  ('y', 6, 7)
# --> 0 words
# **********
#   trying  x
#   trying  xv
#   trying  xa
# **********
# Seed:  ('x', 7, 0)
# --> 0 words
# **********
#   trying  a
#   trying  av
#   trying  at
#   trying  atr
#   trying  ac
#   trying  ack
#   trying  acu
#   trying  acum
#   trying  acc
#   trying  acm
#   trying  ax
#   trying  ac
# **********
# Seed:  ('a', 7, 1)
# --> 0 words
# **********
#   trying  c
#   trying  ct
#   trying  cu
#   trying  cun
#   trying  cuc
#   trying  cuck
#   trying  cum
#     -> match:  cum
#   trying  ca
#   trying  cav
# **********
# Seed:  ('c', 7, 2)
# --> 1 words
# **********
#   trying  m
#   trying  mu
#   trying  muk
#   trying  mun
#   trying  muc
#   trying  muc
#   trying  ma
#   trying  mav
#   trying  maf
#   trying  mah
#   trying  max
#     -> match:  max
#   trying  mh
# **********
# Seed:  ('m', 7, 3)
# --> 1 words
# **********
#   trying  h
#   trying  hu
#   trying  hun
#   trying  hunk
#     -> match:  hunk
#   trying  huc
#   trying  huck
#   trying  hucks
#   trying  huc
#   trying  hum
#     -> match:  hum
#   trying  huma
#   trying  ha
#   trying  hav
#   trying  haf
#   trying  hm
# **********
# Seed:  ('h', 7, 4)
# --> 2 words
# **********
#   trying  x
#   trying  xa
#   trying  xan
#   trying  xc
# **********
# Seed:  ('x', 7, 5)
# --> 0 words
# **********
#   trying  c
#   trying  cy
#   trying  cyl
#   trying  cyt
#   trying  ct
# **********
# Seed:  ('c', 7, 6)
# --> 0 words
# **********
#   trying  t
#   trying  ty
#   trying  tyc
# **********
# Seed:  ('t', 7, 7)
# --> 0 words
# **********
# =======================================================================================================
# 88 words with max 64 letters found in a 8x8 grid after 1.2471871376037598 seconds:
#
#     aft,ankle,auk,big,bight,bights,biro,biz,brie,brine,bring,ceil,cine,cum,elk,eon,fan,fans,fax,fly,foot,foots,fop,gel,gels,giro,girt,goof,goofs,goon,got,him,hrs,hum,hunk,icy,ilk,iron,ironic,lazuli,lbs,leg,lei,max,mug,musk,not,oft,one,pone,pong,poof,poor,pot,pots,rib,rig,rim,rims,ring,roe,roof,roofs,root,rot,skunk,smug,stooge,stop,storm,storms,tack,tacks,tax,ton,tone,tonic,too,top,urge,van,vans,vat,veil,veils,velum,zinc,zing
# =======================================================================================================
